# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
df=pd.read_csv('sonar.csv')
df.head(7)
# Out:
#        V1      V2      V3      V4      V5      V6      V7      V8      V9  \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 5  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# 6  0.0317  0.0956  0.1321  0.1408  0.1674  0.1710  0.0731  0.1401  0.2083
#
#       V10  ...     V52     V53     V54     V55     V56     V57     V58  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# ...

# %%
x=df.iloc[:,0:60].values
y=df.iloc[:,60].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
# from sklearn.preprocessing import StandardScaler
# sc=StandardScaler()
# x_train=sc.fit_transform(x_train)
# x_test=sc.transform(x_test)

# %%
#importing the keras libraries
import keras
from keras.models import Sequential
from keras.layers import Dense #connection btw the layers is done using dense function

# %%
#initialising the ANN
classifier=Sequential()

# %%
#adding the input layer and the first hidden layer
classifier.add(Dense(output_dim=31,init='uniform',activation='relu',input_dim=60))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", input_dim=60, units=31, kernel_initializer="uniform")`

# %%
#adding second hidden layer
classifier.add(Dense(output_dim=31,init='uniform',activation='relu'))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=31, kernel_initializer="uniform")`

# %%
#adding the output layer
classifier.add(Dense(output_dim=1,init='uniform',activation='sigmoid'))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=1, kernel_initializer="uniform")`

# %%
classifier.compile(optimizer='adam',loss='binary_crossentropy', metrics=['accuracy'])

# %%
#fitting the Ann to the training set
classifier.fit(x_train,y_train,batch_size=10,nb_epoch=150)
# Out:
# Epoch 1/150
# 166/166 [==============================] - 0s 96us/step - loss: 0.0537 - acc: 0.9940
# Epoch 2/150
# 166/166 [==============================] - 0s 102us/step - loss: 0.0506 - acc: 0.9940
# Epoch 3/150
# 166/166 [==============================] - 0s 102us/step - loss: 0.0536 - acc: 0.9940
# Epoch 4/150
# 166/166 [==============================] - 0s 102us/step - loss: 0.0565 - acc: 0.9940
# Epoch 5/150
# 166/166 [==============================] - 0s 108us/step - loss: 0.0509 - acc: 0.9940
# Epoch 6/150
# 166/166 [==============================] - 0s 96us/step - loss: 0.0497 - acc: 0.9940
# Epoch 7/150
# 166/166 [==============================] - 0s 96us/step - loss: 0.0471 - acc: 0.9940
# Epoch 8/150
# 166/166 [==============================] - 0s 90us/step - loss: 0.0464 - acc: 0.9940
# Epoch 9/150
# 166/166 [==============================] - 0s 108us/step - loss: 0.0466 - acc: 0.9940
# Epoch 10/150
# ...

# %%
y_pred=classifier.predict(x_test)
y_pred=(y_pred>0.5)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[19,  2],
#        [ 5, 16]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8333333333333334
